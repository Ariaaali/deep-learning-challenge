# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn.ensemble import RandomForestClassifier

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df_clean = application_df.drop(['EIN', 'NAME'], axis=1)
application_df_clean
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df_clean.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
unique_count= application_df_clean['APPLICATION_TYPE'].value_counts()
unique_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
type_counts = application_df_clean['APPLICATION_TYPE'].value_counts()
application_types_to_replace = type_counts[type_counts < 500].index
# Replace in dataframe
for app in application_types_to_replace:
    application_df_clean['APPLICATION_TYPE'] = application_df_clean['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df_clean['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
unique_count_classification= application_df_clean['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
unique_count_classification_above_one = unique_count_classification[unique_count_classification >1]
unique_count_classification_above_one
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = unique_count_classification[unique_count_classification <1000].index
# Replace in dataframe
for cls in classifications_to_replace:
        application_df_clean['CLASSIFICATION'] = application_df_clean['CLASSIFICATION'].replace(cls,"Other")


# Check to make sure replacement was successful
application_df_clean['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
application_df_encoded = pd.get_dummies(application_df_clean)
application_df_encoded_df = application_df_encoded.astype(int)
application_df_encoded_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = application_df_encoded_df["IS_SUCCESSFUL"]
X = application_df_encoded_df.drop(["IS_SUCCESSFUL"], axis=1)

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.41173049653917654, 'ASK_AMT'),
#  (0.14579796095690312, 'AFFILIATION_CompanySponsored'),
#  (0.11040664502440485, 'AFFILIATION_Independent'),
#  (0.02765929606334596, 'ORGANIZATION_Association'),
#  (0.024680826656516955, 'APPLICATION_TYPE_T5'),
#  (0.022237636840339886, 'ORGANIZATION_Trust'),
#  (0.02219137512538043, 'APPLICATION_TYPE_T10'),
#  (0.020487305984497044, 'APPLICATION_TYPE_T4'),
#  (0.01942851779544412, 'CLASSIFICATION_C2100'),
#  (0.018940671613682618, 'CLASSIFICATION_Other'),
#  (0.01807781027018627, 'APPLICATION_TYPE_T19'),
#  (0.01639539667780209, 'CLASSIFICATION_C2000'),
#  (0.016279428338932783, 'APPLICATION_TYPE_T3'),
#  (0.012603593265707268, 'CLASSIFICATION_C1000'),
#  (0.012149506422226907, 'USE_CASE_ProductDev'),
#  (0.010428018963231278, 'APPLICATION_TYPE_T6'),
#  (0.009478654968430032, 'USE_CASE_Preservation'),
#  (0.009205619662859623, 'CLASSIFICATION_C1200'),
#  (0.008967709772273548, 'INCOME_AMT_0'),
#  (0.00655430197603276, 'CLASSIFICATION_C3000'),
#  (0.006481785975017664, 'INCOME_AMT_25000-99999'),
#  (0.006402897606843262, 'INCOME_AMT_1M-5M'),
#  (0.005679931879694543, 'INCOME_AMT_100000-499999'),
#  (0.005650541310885258, 'INCOME_AMT_1-9999'),
#  (0.004545670539638605, 'APPLICATION_TYPE_T8'),
#  (0.0038741358883767796, 'APPLICATION_TYPE_T7'),
#  (0.003229962853560788, 'INCOME_AMT_10M-50M'),
#  (0.0031690477941523376, 'INCOME_AMT_10000-24999'),
#  (0.0030653673558222166, 'USE_CASE_CommunityServ'),
#  (0.0027559649833494566, 'ORGANIZATION_Co-operative'),
#  (0.002267403278051125, 'INCOME_AMT_5M-10M'),
#  (0.002187249673230811, 'INCOME_AMT_50M+'),
#  (0.0019545553712445305, 'APPLICATION_TYPE_Other'),
#  (0.0011976627279182588, 'USE_CASE_Heathcare'),
#  (0.001177608644586264, 'AFFILIATION_Family/Parent'),
#  (0.0006449378088679749, 'AFFILIATION_National'),
#  (0.0006059738730314502, 'ORGANIZATION_Corporation'),
#  (0.00041904107116143936, 'SPECIAL_CONSIDERATIONS_N'),
#  (0.00038062069540573416, 'SPECIAL_CONSIDERATIONS_Y'),
#  (0.00034341190170349796, 'AFFILIATION_Regional'),
#  (0.00013323044894473615, 'STATUS'),
#  (7.175152165319816e-05, 'AFFILIATION_Other'),
#  (6.047387948611779e-05, 'USE_CASE_Other')]

# %%
application_df_encoded_new = X.drop(
    ['AFFILIATION_Other', 'ORGANIZATION_Corporation', 'AFFILIATION_National','AFFILIATION_Family/Parent', 'INCOME_AMT_5M-10M','USE_CASE_Heathcare', 'APPLICATION_TYPE_Other','INCOME_AMT_50M+', 'SPECIAL_CONSIDERATIONS_N', 'SPECIAL_CONSIDERATIONS_Y','STATUS','USE_CASE_Other'],
    axis=1

)

# %%
application_df_encoded_new
# Out:
#         ASK_AMT  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0          5000                     1                     0
# 1        108590                     0                     0
# 2          5000                     0                     0
# 3          6692                     0                     0
# 4        142590                     0                     0
# ...         ...                   ...                   ...
# 34294      5000                     0                     0
# 34295      5000                     0                     0
# 34296      5000                     0                     0
# 34297      5000                     0                     0
# 34298  36500179                     0                     0
#
#        APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                        0                    0                    0
# 1                        1                    0                    0
# 2                        0                    0                    1
# 3                        1                    0                    0
# 4                        1                    0                    0
# ...                    ...                  ...                  ...
# 34294                    0                    1                    0
# 34295                    0                    1                    0
# 34296                    1                    0                    0
# 34297                    0                    0                    1
# 34298                    1                    0                    0
#
#        APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 34294                    0                    0                    0
# 34295                    0                    0                    0
# 34296                    0                    0                    0
# 34297                    0                    0                    0
# 34298                    0                    0                    0
#
#        AFFILIATION_CompanySponsored  ...  ORGANIZATION_Association  \
# 0                                 0  ...                         1
# 1                                 0  ...                         0
# 2                                 1  ...                         1
# 3                                 1  ...                         0
# 4                                 0  ...                         0
# ...                             ...  ...                       ...
# 34294                             0  ...                         1
# 34295                             1  ...                         1
# 34296                             1  ...                         1
# 34297                             0  ...                         1
# 34298                             0  ...                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Trust  INCOME_AMT_0  \
# 0                              0                   0             1
# 1                              1                   0             0
# 2                              0                   0             1
# 3                              0                   1             0
# 4                              0                   1             0
# ...                          ...                 ...           ...
# 34294                          0                   0             1
# 34295                          0                   0             1
# 34296                          0                   0             1
# 34297                          0                   0             1
# 34298                          1                   0             0
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
# [34299 rows x 31 columns]

# %%
y1 = y
X1=application_df_encoded_new.values

# %%
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X1_scaler = scaler.fit(X1_train)

# Scale the data
X1_train_scaled = X1_scaler.transform(X1_train)
X1_test_scaled = X1_scaler.transform(X1_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
number_input_features = len(X1_train[0])
hidden_nodes_layer1 =  20
hidden_nodes_layer2 = 10

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 20)                  │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 861 (3.36 KB)
#  Trainable params: 861 (3.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model_weights_{epoch:02d}.weights.h5',
    save_weights_only=True,
    save_freq=5
)
fit_model=nn.fit(X1_train_scaled, y1_train, epochs=100, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.